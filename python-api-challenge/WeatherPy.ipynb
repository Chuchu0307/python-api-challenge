# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isafjordur
# Processing Record 2 of Set 1 | hawaiian paradise park
# Processing Record 3 of Set 1 | puerto ayacucho
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | mitu
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | atafu village
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | coahuayana de hidalgo
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | palmeira das missoes
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | adamstown
# Processing Record 16 of Set 1 | noosa heads
# Processing Record 17 of Set 1 | baidoa
# Processing Record 18 of Set 1 | chonchi
# Processing Record 19 of Set 1 | puerto natales
# Processing Record 20 of Set 1 | klyuchi
# Processing Record 21 of Set 1 | anadyr
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | jumla
# Processing Record 24 of Set 1 | hammerfest
# Processing Record 25 of Set 1 | brush
# Processing Record 26 of Set 1 | xai-xai
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | port-aux-francais
# Processing Record 29 of Set 1 | tolanaro
# Processing Record 30 of Set 1 | poronaysk
# Processing Record 31 of Set 1 | newman
# Processing Record 32 of Set 1 | bad honningen
# Processing Record 33 of Set 1 | vorkuta
# Processing Record 34 of Set 1 | nelson bay
# Processing Record 35 of Set 1 | banjar
# Processing Record 36 of Set 1 | vilyuchinsk
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | saipan
# Processing Record 39 of Set 1 | puerto baquerizo moreno
# Processing Record 40 of Set 1 | gadzhiyevo
# Processing Record 41 of Set 1 | soham
# Processing Record 42 of Set 1 | nadi
# Processing Record 43 of Set 1 | nuku'alofa
# Processing Record 44 of Set 1 | dudinka
# Processing Record 45 of Set 1 | nacala
# Processing Record 46 of Set 1 | flying fish cove
# Processing Record 47 of Set 1 | blackmans bay
# Processing Record 48 of Set 1 | gizo
# Processing Record 49 of Set 1 | utrik
# Processing Record 50 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 0 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | whitefish
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | grytviken
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | buta
# Processing Record 9 of Set 2 | mesquite
# Processing Record 10 of Set 2 | port mathurin
# Processing Record 11 of Set 2 | shimanovsk
# Processing Record 12 of Set 2 | calatayud
# Processing Record 13 of Set 2 | buenos aires
# Processing Record 14 of Set 2 | stanley
# Processing Record 15 of Set 2 | sao gabriel da cachoeira
# Processing Record 16 of Set 2 | tura
# Processing Record 17 of Set 2 | arkhangel'sk
# Processing Record 18 of Set 2 | isangel
# Processing Record 19 of Set 2 | kone
# Processing Record 20 of Set 2 | south venice
# Processing Record 21 of Set 2 | port elizabeth
# Processing Record 22 of Set 2 | canutama
# Processing Record 23 of Set 2 | geraldton
# Processing Record 24 of Set 2 | greenland
# Processing Record 25 of Set 2 | uturoa
# Processing Record 26 of Set 2 | kingston
# Processing Record 27 of Set 2 | praia da vitoria
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | qaqortoq
# Processing Record 30 of Set 2 | les cayes
# Processing Record 31 of Set 2 | nejo
# Processing Record 32 of Set 2 | broken hill
# Processing Record 33 of Set 2 | faya-largeau
# Processing Record 34 of Set 2 | mahina
# Processing Record 35 of Set 2 | olonkinbyen
# Processing Record 36 of Set 2 | puyang chengguanzhen
# Processing Record 37 of Set 2 | chimore
# Processing Record 38 of Set 2 | suai
# City not found. Skipping...
# Processing Record 39 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 40 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 41 of Set 2 | sitka
# Processing Record 42 of Set 2 | howrah
# Processing Record 43 of Set 2 | keflavik
# Processing Record 44 of Set 2 | minas de marcona
# Processing Record 45 of Set 2 | oromocto
# Processing Record 46 of Set 2 | itaituba
# Processing Record 47 of Set 2 | nogliki
# Processing Record 48 of Set 2 | fort mcmurray
# Processing Record 49 of Set 2 | ruston
# Processing Record 0 of Set 3 | kertih
# Processing Record 1 of Set 3 | jayapura
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | kununurra
# Processing Record 4 of Set 3 | fortaleza
# Processing Record 5 of Set 3 | ungsang-nodongjagu
# Processing Record 6 of Set 3 | wailua homesteads
# Processing Record 7 of Set 3 | porto novo
# Processing Record 8 of Set 3 | aoulef
# Processing Record 9 of Set 3 | edson
# Processing Record 10 of Set 3 | dikhil
# Processing Record 11 of Set 3 | ust-nera
# Processing Record 12 of Set 3 | nova sintra
# Processing Record 13 of Set 3 | kuta
# Processing Record 14 of Set 3 | obihiro
# Processing Record 15 of Set 3 | mil'kovo
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | cestos city
# Processing Record 18 of Set 3 | whistler
# Processing Record 19 of Set 3 | metlili chaamba
# Processing Record 20 of Set 3 | inda silase
# Processing Record 21 of Set 3 | colonia
# Processing Record 22 of Set 3 | ulladulla
# Processing Record 23 of Set 3 | rongelap
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | quibala
# Processing Record 26 of Set 3 | tanrake village
# City not found. Skipping...
# Processing Record 27 of Set 3 | egilsstadir
# Processing Record 28 of Set 3 | constantia
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | zyrya
# Processing Record 31 of Set 3 | kolokani
# Processing Record 32 of Set 3 | lihue
# Processing Record 33 of Set 3 | horsham
# Processing Record 34 of Set 3 | margaret river
# Processing Record 35 of Set 3 | tayu
# Processing Record 36 of Set 3 | bonthe
# Processing Record 37 of Set 3 | hofors
# Processing Record 38 of Set 3 | ozimek
# Processing Record 39 of Set 3 | suhbaatar
# Processing Record 40 of Set 3 | afaahiti
# Processing Record 41 of Set 3 | arti
# Processing Record 42 of Set 3 | susuman
# Processing Record 43 of Set 3 | inongo
# Processing Record 44 of Set 3 | touros
# Processing Record 45 of Set 3 | matola
# Processing Record 46 of Set 3 | corner brook
# Processing Record 47 of Set 3 | den burg
# Processing Record 48 of Set 3 | badger
# Processing Record 49 of Set 3 | garbahaarrey
# Processing Record 0 of Set 4 | prince rupert
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | vavatenina
# Processing Record 3 of Set 4 | kapuskasing
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | siracusa
# Processing Record 8 of Set 4 | la'ie
# Processing Record 9 of Set 4 | west island
# Processing Record 10 of Set 4 | hadibu
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | ola
# Processing Record 13 of Set 4 | taunggyi
# Processing Record 14 of Set 4 | nuuk
# Processing Record 15 of Set 4 | greenville
# Processing Record 16 of Set 4 | bolu
# Processing Record 17 of Set 4 | nanao
# Processing Record 18 of Set 4 | stephenville
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | kroya
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | kayangel
# Processing Record 24 of Set 4 | punta arenas
# Processing Record 25 of Set 4 | likasi
# Processing Record 26 of Set 4 | bargara
# City not found. Skipping...
# Processing Record 27 of Set 4 | college
# Processing Record 28 of Set 4 | bredasdorp
# Processing Record 29 of Set 4 | spencer
# Processing Record 30 of Set 4 | san julian
# Processing Record 31 of Set 4 | afgooye
# Processing Record 32 of Set 4 | xining
# Processing Record 33 of Set 4 | san patricio
# Processing Record 34 of Set 4 | cajamarca
# Processing Record 35 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 36 of Set 4 | kenai
# Processing Record 37 of Set 4 | harstad
# Processing Record 38 of Set 4 | aioun
# Processing Record 39 of Set 4 | morehead city
# Processing Record 40 of Set 4 | lae
# Processing Record 41 of Set 4 | enewetak
# Processing Record 42 of Set 4 | nar'yan-mar
# Processing Record 43 of Set 4 | kamensk-ural'skiy
# Processing Record 44 of Set 4 | horta
# Processing Record 45 of Set 4 | namibe
# Processing Record 46 of Set 4 | nakasongola
# Processing Record 47 of Set 4 | fasa
# Processing Record 48 of Set 4 | chistopol'
# Processing Record 49 of Set 4 | alice springs
# Processing Record 0 of Set 5 | yemel'yanovo
# Processing Record 1 of Set 5 | barra de santo antonio
# Processing Record 2 of Set 5 | auburn
# Processing Record 3 of Set 5 | udachny
# Processing Record 4 of Set 5 | invercargill
# Processing Record 5 of Set 5 | bada
# Processing Record 6 of Set 5 | rawson
# Processing Record 7 of Set 5 | qarauyl
# Processing Record 8 of Set 5 | arraial do cabo
# Processing Record 9 of Set 5 | charlottetown
# Processing Record 10 of Set 5 | palikir - national government center
# Processing Record 11 of Set 5 | ha'il
# Processing Record 12 of Set 5 | choibalsan
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | brokopondo
# Processing Record 15 of Set 5 | vorgashor
# Processing Record 16 of Set 5 | st. john's
# Processing Record 17 of Set 5 | igarka
# Processing Record 18 of Set 5 | chinde
# Processing Record 19 of Set 5 | hithadhoo
# Processing Record 20 of Set 5 | camabatela
# Processing Record 21 of Set 5 | langepas
# Processing Record 22 of Set 5 | hayma'
# City not found. Skipping...
# Processing Record 23 of Set 5 | barah
# Processing Record 24 of Set 5 | benguela
# Processing Record 25 of Set 5 | morsi
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | iskateley
# Processing Record 28 of Set 5 | tinogasta
# Processing Record 29 of Set 5 | northam
# Processing Record 30 of Set 5 | funafuti
# Processing Record 31 of Set 5 | lompoc
# Processing Record 32 of Set 5 | westport
# Processing Record 33 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 5 | aykhal
# Processing Record 35 of Set 5 | papatowai
# Processing Record 36 of Set 5 | qandala
# Processing Record 37 of Set 5 | tazacorte
# Processing Record 38 of Set 5 | shenjiamen
# Processing Record 39 of Set 5 | neryungri
# Processing Record 40 of Set 5 | defuniak springs
# Processing Record 41 of Set 5 | taroa
# Processing Record 42 of Set 5 | sangin
# Processing Record 43 of Set 5 | holualoa
# Processing Record 44 of Set 5 | rio claro
# Processing Record 45 of Set 5 | andapa
# Processing Record 46 of Set 5 | cabo san lucas
# Processing Record 47 of Set 5 | tralee
# Processing Record 48 of Set 5 | hami
# Processing Record 49 of Set 5 | saldanha
# Processing Record 0 of Set 6 | emerald
# Processing Record 1 of Set 6 | thunder bay
# Processing Record 2 of Set 6 | yadrin
# Processing Record 3 of Set 6 | bacalar
# Processing Record 4 of Set 6 | sechura
# Processing Record 5 of Set 6 | kaduy
# Processing Record 6 of Set 6 | mili
# Processing Record 7 of Set 6 | molina
# Processing Record 8 of Set 6 | bel ombre
# Processing Record 9 of Set 6 | pawai
# Processing Record 10 of Set 6 | enriquillo
# Processing Record 11 of Set 6 | ordos
# City not found. Skipping...
# Processing Record 12 of Set 6 | la rinconada
# Processing Record 13 of Set 6 | kashgar
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | al bayda'
# Processing Record 16 of Set 6 | agat village
# Processing Record 17 of Set 6 | lagos de moreno
# Processing Record 18 of Set 6 | nahrin
# Processing Record 19 of Set 6 | timbuktu
# Processing Record 20 of Set 6 | nongstoin
# Processing Record 21 of Set 6 | vikhorevka
# Processing Record 22 of Set 6 | queenstown
# Processing Record 23 of Set 6 | sao raimundo nonato
# Processing Record 24 of Set 6 | san matias
# Processing Record 25 of Set 6 | bellbrook
# Processing Record 26 of Set 6 | piton saint-leu
# Processing Record 27 of Set 6 | port hedland
# Processing Record 28 of Set 6 | kapa'a
# Processing Record 29 of Set 6 | govardhan
# Processing Record 30 of Set 6 | nemuro
# Processing Record 31 of Set 6 | saint helena
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | collie
# Processing Record 34 of Set 6 | sangmelima
# Processing Record 35 of Set 6 | el calafate
# Processing Record 36 of Set 6 | cumbal
# Processing Record 37 of Set 6 | alofi
# Processing Record 38 of Set 6 | kirkwood
# Processing Record 39 of Set 6 | mana
# Processing Record 40 of Set 6 | neon karlovasion
# Processing Record 41 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 42 of Set 6 | lospalos
# Processing Record 43 of Set 6 | chengde
# Processing Record 44 of Set 6 | manggar
# Processing Record 45 of Set 6 | turpan
# Processing Record 46 of Set 6 | minab
# Processing Record 47 of Set 6 | pizarro
# Processing Record 48 of Set 6 | santa ana de yacuma
# Processing Record 49 of Set 6 | new plymouth
# Processing Record 0 of Set 7 | kuusamo
# Processing Record 1 of Set 7 | yagry
# City not found. Skipping...
# Processing Record 2 of Set 7 | kattivakkam
# Processing Record 3 of Set 7 | tabas
# Processing Record 4 of Set 7 | ciudad bolivar
# Processing Record 5 of Set 7 | whitehorse
# Processing Record 6 of Set 7 | onsala
# Processing Record 7 of Set 7 | bombarral
# Processing Record 8 of Set 7 | adam
# Processing Record 9 of Set 7 | aasiaat
# Processing Record 10 of Set 7 | plastun
# Processing Record 11 of Set 7 | rengasdengklok
# Processing Record 12 of Set 7 | kushva
# Processing Record 13 of Set 7 | tazovsky
# Processing Record 14 of Set 7 | boca suno
# Processing Record 15 of Set 7 | carnarvon
# Processing Record 16 of Set 7 | midvagur
# Processing Record 17 of Set 7 | tiquipaya
# Processing Record 18 of Set 7 | torrington
# Processing Record 19 of Set 7 | mahibadhoo
# Processing Record 20 of Set 7 | pisco
# Processing Record 21 of Set 7 | okha
# Processing Record 22 of Set 7 | alangalang
# Processing Record 23 of Set 7 | port alfred
# Processing Record 24 of Set 7 | smithers
# Processing Record 25 of Set 7 | las heras
# Processing Record 26 of Set 7 | arraias
# Processing Record 27 of Set 7 | carupano
# Processing Record 28 of Set 7 | colon
# Processing Record 29 of Set 7 | kentville
# Processing Record 30 of Set 7 | necochea
# Processing Record 31 of Set 7 | fortuna
# Processing Record 32 of Set 7 | sao joao da barra
# Processing Record 33 of Set 7 | walker
# Processing Record 34 of Set 7 | kolonia town
# Processing Record 35 of Set 7 | acarau
# Processing Record 36 of Set 7 | bamboo flat
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | tromso
# Processing Record 39 of Set 7 | port macquarie
# Processing Record 40 of Set 7 | fort bragg
# Processing Record 41 of Set 7 | akureyri
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | baikunthpur
# Processing Record 44 of Set 7 | chui
# Processing Record 45 of Set 7 | kudymkar
# Processing Record 46 of Set 7 | brookings
# Processing Record 47 of Set 7 | karoi
# Processing Record 48 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record 49 of Set 7 | hirara
# Processing Record 0 of Set 8 | burabay
# Processing Record 1 of Set 8 | pasuquin
# Processing Record 2 of Set 8 | recani
# Processing Record 3 of Set 8 | mersa matruh
# Processing Record 4 of Set 8 | kuanda
# Processing Record 5 of Set 8 | dickinson
# Processing Record 6 of Set 8 | gornozavodsk
# Processing Record 7 of Set 8 | belyy yar
# Processing Record 8 of Set 8 | selfoss
# Processing Record 9 of Set 8 | fale old settlement
# Processing Record 10 of Set 8 | bengkulu
# Processing Record 11 of Set 8 | la passe
# Processing Record 12 of Set 8 | juneau
# Processing Record 13 of Set 8 | la reforma
# Processing Record 14 of Set 8 | soure
# Processing Record 15 of Set 8 | abraham's bay
# City not found. Skipping...
# Processing Record 16 of Set 8 | antofagasta
# Processing Record 17 of Set 8 | troitsko-pechorsk
# Processing Record 18 of Set 8 | langsa
# Processing Record 19 of Set 8 | nur-sultan
# Processing Record 20 of Set 8 | tocopilla
# Processing Record 21 of Set 8 | san antonio de pale
# Processing Record 22 of Set 8 | berdigestyakh
# Processing Record 23 of Set 8 | pangai
# Processing Record 24 of Set 8 | omdurman
# Processing Record 25 of Set 8 | nan
# Processing Record 26 of Set 8 | makhambet
# Processing Record 27 of Set 8 | mejit
# Processing Record 28 of Set 8 | mandera
# Processing Record 29 of Set 8 | tam ky
# Processing Record 30 of Set 8 | acajutla
# Processing Record 31 of Set 8 | imeko
# Processing Record 32 of Set 8 | eastham
# Processing Record 33 of Set 8 | skowhegan
# Processing Record 34 of Set 8 | basni
# Processing Record 35 of Set 8 | nantucket
# Processing Record 36 of Set 8 | new norfolk
# Processing Record 37 of Set 8 | yaren
# Processing Record 38 of Set 8 | tongliao
# Processing Record 39 of Set 8 | villa union
# Processing Record 40 of Set 8 | little falls
# Processing Record 41 of Set 8 | sosnovo-ozerskoye
# Processing Record 42 of Set 8 | vilyuysk
# Processing Record 43 of Set 8 | ras al khaimah city
# Processing Record 44 of Set 8 | yuzhno-kurilsk
# Processing Record 45 of Set 8 | rio das ostras
# Processing Record 46 of Set 8 | soio
# Processing Record 47 of Set 8 | yerofey pavlovich
# Processing Record 48 of Set 8 | lara
# Processing Record 49 of Set 8 | happy valley-goose bay
# Processing Record 0 of Set 9 | jianshui
# Processing Record 1 of Set 9 | karaton
# Processing Record 2 of Set 9 | nizhniy odes
# Processing Record 3 of Set 9 | lakhipur
# Processing Record 4 of Set 9 | qamdo
# Processing Record 5 of Set 9 | kudahuvadhoo
# Processing Record 6 of Set 9 | kristiansund
# Processing Record 7 of Set 9 | ta`u
# Processing Record 8 of Set 9 | dunedin
# Processing Record 9 of Set 9 | onega
# Processing Record 10 of Set 9 | labuan
# Processing Record 11 of Set 9 | great falls
# Processing Record 12 of Set 9 | el nido
# Processing Record 13 of Set 9 | crossett
# Processing Record 14 of Set 9 | xinyang
# Processing Record 15 of Set 9 | marabba
# Processing Record 16 of Set 9 | saint-philippe
# Processing Record 17 of Set 9 | canavieiras
# Processing Record 18 of Set 9 | illizi
# Processing Record 19 of Set 9 | adamovka
# Processing Record 20 of Set 9 | mogocha
# Processing Record 21 of Set 9 | manokwari
# Processing Record 22 of Set 9 | severo-yeniseyskiy
# Processing Record 23 of Set 9 | mount isa
# Processing Record 24 of Set 9 | charters towers
# Processing Record 25 of Set 9 | turuntayevo
# Processing Record 26 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 27 of Set 9 | thurles
# Processing Record 28 of Set 9 | cabedelo
# Processing Record 29 of Set 9 | tsarevo
# Processing Record 30 of Set 9 | nuriootpa
# Processing Record 31 of Set 9 | ejido benito juarez
# City not found. Skipping...
# Processing Record 32 of Set 9 | mar del plata
# Processing Record 33 of Set 9 | iquique
# Processing Record 34 of Set 9 | qaisumah
# Processing Record 35 of Set 9 | impfondo
# Processing Record 36 of Set 9 | yung shue wan
# Processing Record 37 of Set 9 | beloyarskiy
# Processing Record 38 of Set 9 | ikwiriri
# Processing Record 39 of Set 9 | jiuquan
# Processing Record 40 of Set 9 | ingeniero jacobacci
# Processing Record 41 of Set 9 | sena madureira
# Processing Record 42 of Set 9 | kailua-kona
# Processing Record 43 of Set 9 | mount gambier
# Processing Record 44 of Set 9 | kerikeri
# Processing Record 45 of Set 9 | bayanaul
# Processing Record 46 of Set 9 | gross-zimmern
# Processing Record 47 of Set 9 | soufriere
# Processing Record 48 of Set 9 | tortoli
# Processing Record 49 of Set 9 | aguilar de campoo
# Processing Record 0 of Set 10 | akko
# Processing Record 1 of Set 10 | kyzyl-burun
# City not found. Skipping...
# Processing Record 2 of Set 10 | port lincoln
# Processing Record 3 of Set 10 | saguenay
# Processing Record 4 of Set 10 | zhangye
# Processing Record 5 of Set 10 | phanom thuan
# Processing Record 6 of Set 10 | sola
# Processing Record 7 of Set 10 | marquette
# Processing Record 8 of Set 10 | zaysan
# Processing Record 9 of Set 10 | concepcion del bermejo
# Processing Record 10 of Set 10 | meadow lakes
# Processing Record 11 of Set 10 | thai binh
# Processing Record 12 of Set 10 | fuerte olimpo
# Processing Record 13 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 14 of Set 10 | whakatane
# Processing Record 15 of Set 10 | namdrik
# Processing Record 16 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 17 of Set 10 | bikenibeu village
# Processing Record 18 of Set 10 | guardo
# Processing Record 19 of Set 10 | kupang
# Processing Record 20 of Set 10 | weno
# Processing Record 21 of Set 10 | birstein
# Processing Record 22 of Set 10 | oranjemund
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | dhidhdhoo
# Processing Record 25 of Set 10 | mohammedia
# Processing Record 26 of Set 10 | iguape
# Processing Record 27 of Set 10 | rechka-vydrino
# Processing Record 28 of Set 10 | island harbour
# Processing Record 29 of Set 10 | bayville
# Processing Record 30 of Set 10 | reggane
# Processing Record 31 of Set 10 | puerto santander
# Processing Record 32 of Set 10 | san-pedro
# Processing Record 33 of Set 10 | north bend
# Processing Record 34 of Set 10 | najran
# Processing Record 35 of Set 10 | beroroha
# Processing Record 36 of Set 10 | dongcun
# Processing Record 37 of Set 10 | ilanskiy
# Processing Record 38 of Set 10 | terek
# Processing Record 39 of Set 10 | pont rouge
# Processing Record 40 of Set 10 | sayan
# Processing Record 41 of Set 10 | vila franca do campo
# Processing Record 42 of Set 10 | amga
# Processing Record 43 of Set 10 | port saint john's
# Processing Record 44 of Set 10 | krasavino
# Processing Record 45 of Set 10 | cromwell
# Processing Record 46 of Set 10 | crane
# Processing Record 47 of Set 10 | borogontsy
# Processing Record 48 of Set 10 | akbarpur
# Processing Record 49 of Set 10 | mermoz boabab
# Processing Record 0 of Set 11 | murghob
# Processing Record 1 of Set 11 | chilca
# Processing Record 2 of Set 11 | sinnar
# Processing Record 3 of Set 11 | harrison
# Processing Record 4 of Set 11 | zanjan
# Processing Record 5 of Set 11 | las tablas
# Processing Record 6 of Set 11 | sinop
# Processing Record 7 of Set 11 | korhogo
# Processing Record 8 of Set 11 | malango
# Processing Record 9 of Set 11 | tukrah
# Processing Record 10 of Set 11 | buenaventura
# Processing Record 11 of Set 11 | ocean city
# Processing Record 12 of Set 11 | lys'va
# Processing Record 13 of Set 11 | nova vicosa
# Processing Record 14 of Set 11 | punta del este
# Processing Record 15 of Set 11 | ust'-ilimsk
# Processing Record 16 of Set 11 | kawalu
# Processing Record 17 of Set 11 | dakhla
# Processing Record 18 of Set 11 | san pedro buenavista
# Processing Record 19 of Set 11 | ratnagiri
# Processing Record 20 of Set 11 | barcelos
# Processing Record 21 of Set 11 | zhaotong
# Processing Record 22 of Set 11 | araguaina
# Processing Record 23 of Set 11 | buka
# Processing Record 24 of Set 11 | acapulco de juarez
# Processing Record 25 of Set 11 | haiku-pauwela
# Processing Record 26 of Set 11 | ambovombe
# Processing Record 27 of Set 11 | ghanzi
# Processing Record 28 of Set 11 | tutoia
# Processing Record 29 of Set 11 | hotan
# Processing Record 30 of Set 11 | magong
# Processing Record 31 of Set 11 | castillos
# Processing Record 32 of Set 11 | sandnessjoen
# Processing Record 33 of Set 11 | magadan
# Processing Record 34 of Set 11 | tres lagoas
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | sabang
# Processing Record 37 of Set 11 | santa elena de uairen
# Processing Record 38 of Set 11 | trashi yangtse
# Processing Record 39 of Set 11 | ulsteinvik
# Processing Record 40 of Set 11 | argo
# Processing Record 41 of Set 11 | saint simons island
# City not found. Skipping...
# Processing Record 42 of Set 11 | irymple
# Processing Record 43 of Set 11 | ivdel'
# Processing Record 44 of Set 11 | buala
# Processing Record 45 of Set 11 | dryden
# Processing Record 46 of Set 11 | antonio enes
# Processing Record 47 of Set 11 | shagonar
# Processing Record 48 of Set 11 | saint-pierre
# Processing Record 49 of Set 11 | tahoua
# Processing Record 0 of Set 12 | butia
# Processing Record 1 of Set 12 | kiuruvesi
# Processing Record 2 of Set 12 | preobrazheniye
# Processing Record 3 of Set 12 | sinabang
# Processing Record 4 of Set 12 | salinopolis
# Processing Record 5 of Set 12 | hailey
# Processing Record 6 of Set 12 | khovd
# Processing Record 7 of Set 12 | inirida
# Processing Record 8 of Set 12 | yokadouma
# Processing Record 9 of Set 12 | bol'shoye boldino
# Processing Record 10 of Set 12 | beledweyne
# Processing Record 11 of Set 12 | kill devil hills
# Processing Record 12 of Set 12 | chibuto
# Processing Record 13 of Set 12 | inari
# Processing Record 14 of Set 12 | vernon
# Processing Record 15 of Set 12 | miracema do tocantins
# Processing Record 16 of Set 12 | raduzhny
# Processing Record 17 of Set 12 | salekhard
# Processing Record 18 of Set 12 | mount pearl
# Processing Record 19 of Set 12 | granada
# Processing Record 20 of Set 12 | maun
# Processing Record 21 of Set 12 | el granada
# Processing Record 22 of Set 12 | linfen
# Processing Record 23 of Set 12 | kawthoung
# City not found. Skipping...
# Processing Record 24 of Set 12 | porbandar
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | bodo
# Processing Record 27 of Set 12 | chitipa
# Processing Record 28 of Set 12 | lautoka
# Processing Record 29 of Set 12 | bereznik
# Processing Record 30 of Set 12 | zmeinogorsk
# Processing Record 31 of Set 12 | tamanrasset
# Processing Record 32 of Set 12 | slave lake
# Processing Record 33 of Set 12 | belmonte
# Processing Record 34 of Set 12 | lensk
# Processing Record 35 of Set 12 | trinidad
# Processing Record 36 of Set 12 | archangelos
# Processing Record 37 of Set 12 | shippensburg
# Processing Record 38 of Set 12 | upington
# Processing Record 39 of Set 12 | comodoro rivadavia
# Processing Record 40 of Set 12 | tommot
# Processing Record 41 of Set 12 | gorontalo
# Processing Record 42 of Set 12 | novokruchininskiy
# Processing Record 43 of Set 12 | howard springs
# Processing Record 44 of Set 12 | smidovich
# Processing Record 45 of Set 12 | kombissiri
# Processing Record 46 of Set 12 | wlodawa
# Processing Record 47 of Set 12 | mahajanga
# Processing Record 48 of Set 12 | carutapera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                   isafjordur  66.0755  -23.1240    265.01        73
# 1       hawaiian paradise park  19.5933 -154.9731    296.41        81
# 2              puerto ayacucho   5.6639  -67.6236    297.87        91
# 3                     waitangi -43.9535 -176.5597    292.49        85
# 4                       albany  42.6001  -73.9662    274.67        68
# 5                         mitu   1.1983  -70.1733    297.45        88
# 6  edinburgh of the seven seas -37.0676  -12.3116    290.28        67
# 7                atafu village  -8.5421 -172.5159    301.55        79
# 8                 kruisfontein -34.0033   24.7314    290.86        78
# 9        coahuayana de hidalgo  18.7000 -103.6583    295.57        91
#
#    Cloudiness  Wind Speed Country        Date
# 0           1        1.63      IS  1707361799
# 1         100        2.06      US  1707362025
# 2          89        1.93      VE  1707361758
# 3         100        2.33      NZ  1707361793
# 4          38        0.72      US  1707361948
# 5          73        0.23      CO  1707362027
# 6         100        2.88      SH  1707361797
# 7         100        8.48      TK  1707361806
# 8           4        3.83      ZA  1707362028
# 9          21        0.79      MX  1707362028

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          578
# Lat           578
# Lng           578
# Max Temp      578
# Humidity      578
# Cloudiness    578
# Wind Speed    578
# Country       578
# Date          578
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              isafjordur  66.0755  -23.1240    265.01        73           1
# 1  hawaiian paradise park  19.5933 -154.9731    296.41        81         100
# 2         puerto ayacucho   5.6639  -67.6236    297.87        91          89
# 3                waitangi -43.9535 -176.5597    292.49        85         100
# 4                  albany  42.6001  -73.9662    274.67        68          38
#
#    Wind Speed Country        Date
# 0        1.63      IS  1707361799
# 1        2.06      US  1707362025
# 2        1.93      VE  1707361758
# 3        2.33      NZ  1707361793
# 4        0.72      US  1707361948

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    isafjordur  66.0755  -23.1240    265.01        73
# 1        hawaiian paradise park  19.5933 -154.9731    296.41        81
# 2               puerto ayacucho   5.6639  -67.6236    297.87        91
# 3                      waitangi -43.9535 -176.5597    292.49        85
# 4                        albany  42.6001  -73.9662    274.67        68
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 1        1.63      IS  1707361799
# 1               100        2.06      US  1707362025
# 2                89        1.93      VE  1707361758
# 3               100        2.33      NZ  1707361793
# 4                38        0.72      US  1707361948

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature 2022-10-18") 
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity 2022-10-18") 
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2022-10-18)") 
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2022-10-18)") 
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Create line equation string

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, fontsize=15,color="red")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/chuchu/Desktop/Class_Folder/Module 6/Starter_Code/python-api-challenge/WeatherPy.ipynb Cell 22 line 9
#       <a href='vscode-notebook-cell:/Users/chuchu/Desktop/Class_Folder/Module%206/Starter_Code/python-api-challenge/WeatherPy.ipynb#X31sZmlsZQ%3D%3D?line=6'>7</a> plt.scatter(x_values, y_values)
#       <a href='vscode-notebook-cell:/Users/chuchu/Desktop/Class_Folder/Module%206/Starter_Code/python-api-challenge/WeatherPy.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> plt.plot(x_values,regress_values,"r-")
# ----> <a href='vscode-notebook-cell:/Users/chuchu/Desktop/Class_Folder/Module%206/Starter_Code/python-api-challenge/WeatherPy.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a> plt.annotate(line_eq, fontsize=15,color="red")
#
# TypeError: annotate() missing 1 required positional argument: 'xy'

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                    isafjordur  66.0755  -23.1240    265.01        73
# 1        hawaiian paradise park  19.5933 -154.9731    296.41        81
# 2               puerto ayacucho   5.6639  -67.6236    297.87        91
# 4                        albany  42.6001  -73.9662    274.67        68
# 5                          mitu   1.1983  -70.1733    297.45        88
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 1        1.63      IS  1707361799
# 1               100        2.06      US  1707362025
# 2                89        1.93      VE  1707361758
# 4                38        0.72      US  1707361948
# 5                73        0.23      CO  1707362027

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                           waitangi -43.9535 -176.5597    292.49        85
# 6        edinburgh of the seven seas -37.0676  -12.3116    290.28        67
# 7                      atafu village  -8.5421 -172.5159    301.55        79
# 8                       kruisfontein -34.0033   24.7314    290.86        78
# 10                              lebu -37.6167  -73.6500    286.96        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3               100        2.33      NZ  1707361793
# 6               100        2.88      SH  1707361797
# 7               100        8.48      TK  1707361806
# 8                 4        3.83      ZA  1707362028
# 10               96        8.97      CL  1707361795

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5, 45),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.8906911870922449

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20, -5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.546826317526414

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5, 45),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.46262277107986716

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, -5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.31714400490958394

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,70),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.30067951969485723

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30, -10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.29817373434363764

# %% [markdown]
# **Discussion about the linear relationship:**
# # positive relationship

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,70),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.09417904976048949

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50, -25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.247223823887733

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#very weak correlation
